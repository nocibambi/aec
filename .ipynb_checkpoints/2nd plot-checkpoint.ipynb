# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np

# %%
import quandl
quandl.ApiConfig.api_key = "ybsysG4Eemy9AWq9_Kfc"

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the data

# %%
h0 = pd.read_stata("H0_cpy_all.dta")

# %%
comnames = pd.read_excel("UN Comtrade Commodity Classifications.xlsx") # from http://unstats.un.org/unsd/tradekb/Attachment439.aspx?AttachmentType=1
comnames = comnames[(comnames.Classification == 'H5')]

# %%
ucom_codes = pd.read_csv('UCOM-datasets-codes.csv') # https://www.quandl.com/data/UCOM-United-Nations-Commodity-Trade/usage/export

# %% [markdown]
# # Identifying the most effective export products of a country with high opportunity value

# %%
comtoexp = h0[(h0.year == 2016)].drop(columns=['year', 'population']).copy()

# %%
comtoexp[
    (comtoexp.exporter == 'IDN')
    & (comtoexp.oppgain != 0)].sort_values(by='rca', ascending=False).head(30).sort_values(by='oppgain', ascending=False)
# Out:
#         exporter commoditycode  inatlas  export_value       rca      rpop  \
# 6015696      IDN          3906        1  1.203777e+08  0.874630  0.281450
# 6016107      IDN          7320        1  6.158685e+07  0.965894  0.310818
# 6015690      IDN          3823        1  4.206575e+08  0.917116  0.295121
# 6016307      IDN          8507        1  3.511796e+08  0.863309  0.277807
# 6016387      IDN          9001        1  2.363316e+08  0.946537  0.304589
# 6016091      IDN          7304        1  1.795441e+08  0.847914  0.272853
# 6016004      IDN          6813        1  1.536922e+07  0.989428  0.318391
# 6016207      IDN          8303        1  1.066536e+07  0.850828  0.273790
# 6015675      IDN          3808        1  2.776491e+08  0.851393  0.273972
# 6016233      IDN          8418        1  4.095482e+08  0.949633  0.305585
# 6015874      IDN          5501        1  1.115096e+07  0.996087  0.320534
# 6015676      IDN          3809        1  3.840460e+07  0.936054  0.301216
# 6015759      IDN          4405        1  7.567250e+05  0.965126  0.310571
# 6016033      IDN          7013        1  7.178110e+07  0.855671  0.275349
# 6015710      IDN          3920        1  4.932099e+08  0.922681  0.296912
# 6015642      IDN          3402        1  2.699988e+08  0.857586  0.275965
# 6016018      IDN          6912        1  2.485658e+07  0.882604  0.284016
# 6015866      IDN          5401        1  1.108802e+07  0.959250  0.308680
# 6015684      IDN          3817        1  1.912377e+07  0.897933  0.288949
# 6016328      IDN          8528        1  7.366196e+08  0.940501  0.302646
# 6016458      IDN          9503        1  4.472376e+08  0.948573  0.305244
# 6015940      IDN          6113        1  1.144809e+07  0.937455  0.301666
# 6016164      IDN          7902        1  4.468432e+06  0.877240  0.282289
# 6015897      IDN          5608        1  1.724456e+07  0.987809  0.317870
# 6015850      IDN          5208        1  1.136008e+08  0.855792  0.275388
# 6015736      IDN          4103        1  5.411371e+06  0.874794  0.281503
# 6015934      IDN          6107        1  6.356399e+07  0.879110  0.282891
# 6015402      IDN          1801        1  1.022642e+08  0.903719  0.290810
# 6015471      IDN          2523        1  1.006215e+08  0.999089  0.321500
# 6015507      IDN          2709        1  5.324622e+09  0.859463  0.276569
#
#          mcp       eci       pci    oppval   oppgain  distance  import_value
# 6015696    0 -0.306436  3.549678  2.017173  1.375214  0.858848  1.685783e+08
# 6016107    0 -0.306436  2.760722  2.017173  1.110544  0.833846  6.319412e+07
# 6015690    0 -0.306436  2.269975  2.017173  1.029126  0.837574  3.757021e+08
# 6016307    0 -0.306436  2.098567  2.017173  0.913961  0.794814  2.750838e+08
# 6016387    0 -0.306436  2.205543  2.017173  0.874201  0.810426  9.607457e+07
# 6016091    0 -0.306436  1.851715  2.017173  0.866979  0.831914  2.874269e+08
# 6016004    0 -0.306436  1.254636  2.017173  0.854599  0.829606  3.388543e+07
# 6016207    0 -0.306436  2.132031  2.017173  0.804965  0.810935  1.078461e+07
# 6015675    0 -0.306436  1.794060  2.017173  0.794174  0.833848  4.170464e+08
# 6016233    0 -0.306436  1.915654  2.017173  0.756746  0.803733  3.241991e+08
# 6015874    0 -0.306436  1.292547  2.017173  0.750785  0.800655  8.857746e+07
# 6015676    0 -0.306436  1.252381  2.017173  0.726423  0.809769  9.783488e+07
# 6015759    0 -0.306436  1.414868  2.017173  0.722990  0.821670  5.156065e+06
# 6016033    0 -0.306436  1.533054  2.017173  0.675952  0.815296  3.591371e+07
# 6015710    0 -0.306436  1.302460  2.017173  0.648334  0.793402  5.030098e+08
# 6015642    0 -0.306436  1.054831  2.017173  0.637408  0.801659  2.536342e+08
# 6016018    0 -0.306436  1.288423  2.017173  0.597521  0.807622  1.020897e+06
# 6015866    0 -0.306436  0.264652  2.017173  0.533678  0.782078  2.271532e+07
# 6015684    0 -0.306436  0.352142  2.017173  0.524614  0.821937  5.843464e+07
# 6016328    0 -0.306436  1.316845  2.017173  0.495759  0.779058  3.538838e+08
# 6016458    0 -0.306436  1.647190  2.017173  0.437605  0.799798  1.645100e+08
# 6015940    0 -0.306436 -0.341243  2.017173  0.302734  0.756149  6.373510e+05
# 6016164    0 -0.306436 -0.465890  2.017173  0.275900  0.762603  2.283600e+05
# 6015897    0 -0.306436 -0.090700  2.017173  0.216945  0.752642  2.732268e+07
# 6015850    0 -0.306436 -1.585608  2.017173  0.121281  0.773375  3.776781e+08
# 6015736    0 -0.306436 -2.865018  2.017173 -0.018379  0.734457  2.309285e+06
# 6015934    0 -0.306436 -1.540036  2.017173 -0.018677  0.695909  7.413127e+06
# 6015402    0 -0.306436 -3.978386  2.017173 -0.068918  0.713871  1.795423e+08
# 6015471    0 -0.306436 -1.572682  2.017173 -0.109451  0.726017  3.797575e+07
# 6015507    0 -0.306436 -3.855992  2.017173 -0.172183  0.696705  5.642843e+09

# %%
comnames[comnames.Code == str(3906)] # Identifying the product with the highest opportunity value
# Out:
#       Classification  Code                        Description Code Parent  \
# 34828             H5  3906  Acrylic polymers in primary forms          39
#
#        Level  isLeaf
# 34828      4       0

# %%
comnames[comnames.Code == str(39)] # Identifying the product group into which it belongs
# Out:
#       Classification Code                    Description Code Parent  Level  \
# 34792             H5   39  Plastics and articles thereof       TOTAL      2
#
#        isLeaf
# 34792       0

# %% [markdown]
# # Acquiring trading data for that product type

# %%
plas_dat = pd.read_csv('plas_dat.csv') # I complied this data from the UN Comtrade API.
plas_dat.drop(columns='Date', inplace=True)
# Because it takes a while to download it, I wrote out the table into a file.
# Below you can find the steps I made.

# %% [raw]
# plas_query = ucom_codes[ucom_codes.iloc[:,0].str[5:-4] == 'PLAS'].iloc[:,0]

# %% [raw]
# plas_query.shape

# %% [raw]
# plas_query.head()

# %% [raw]
# plas_dat = pd.DataFrame()
#
#
# for i in range(len(plas_query)):
#     countrycode = plas_query.iloc[i]
#     row = quandl.get(countrycode, start_date='2016-12-31', end_date='2016-12-31')
#
#     if plas_dat.shape == (0,0):
#         plas_dat=pd.DataFrame(row)
#
#     else:
#         plas_dat = plas_dat.append(row)
#
# plas_dat

# %% [raw]
# plas_dat.to_csv('plas_dat.csv')

# %% [markdown]
# # Rendering the plot

# %% [markdown]
# We focus only on the simple import values

# %%
imp_cols = (plas_dat.columns.str[-20:] == 'Import - Trade (USD)') & (plas_dat.columns.str[-23:] != 'Re-Import - Trade (USD)')
imp_dat = plas_dat.loc[:,imp_cols].dropna(how='all')
imp_dat.head()
# Out:
#    Acrylic polymers nes; in primary forms - Import - Trade (USD)  \
# 0                                                NaN
# 1                                         75874557.0
# 2                                             1482.0
# 3                                        111884626.0
# 4                                          8046155.0
#
#    Acrylonitrile-butadiene-styrene (ABS) copolymers - Import - Trade (USD)  \
# 0                                                NaN
# 1                                          9929185.0
# 2                                                NaN
# 3                                         14139630.0
# 4                                                NaN
#
#    Alginic acid; its salts & esters; in primary forms - Import - Trade (USD)  \
# 0                                                NaN
# 1                                          3087589.0
# 2                                                NaN
# 3                                          2131778.0
# 4                                                NaN
#
#    Alkyd resins; in primary forms - Import - Trade (USD)  \
# 0                                                NaN
# 1                                         11234050.0
# 2                                           245011.0
# 3                                           302686.0
# 4                                           539473.0
#
#    Amino-resins nes; in primary forms - Import - Trade (USD)  \
# 0                                                NaN
# 1                                         15904042.0
# 2                                                NaN
# 3                                         22266725.0
# 4                                           583635.0
#
#    Bathroom wares nes; of plastics - Import - Trade (USD)  \
# 0                                                NaN
# 1                                          8997130.0
# 2                                            36382.0
# 3                                           827146.0
# 4                                          2524783.0
#
#    Baths; shower-baths and wash basins; of plastics - Import - Trade (USD)  \
# 0                                                NaN
# 1                                          6433072.0
# 2                                           108210.0
# 3                                          4219622.0
# 4                                           627635.0
#
#    Boxes; cases; crates etc. of plastic - Import - Trade (USD)  \
# 0                                                NaN
# 1                                          7858921.0
# 2                                           122637.0
# 3                                         17781391.0
# 4                                          2854302.0
#
#    Carboxymethylcellulose; salts; in primary forms - Import - Trade (USD)  \
# 0                                                NaN
# 1                                          6851113.0
# 2                                                NaN
# 3                                          8338867.0
# 4                                            57589.0
#
#    Cellulose acetates; non-plasticised; in primary forms - Import - Trade (USD)  \
# 0                                                NaN
# 1                                         20686770.0
# 2                                              271.0
# 3                                            45667.0
# 4                                                NaN
#
#                                    ...                                   \
# 0                                  ...
# 1                                  ...
# 2                                  ...
# 3                                  ...
# 4                                  ...
#
#    Silicones in primary forms - Import - Trade (USD)  \
# 0                                                NaN
# 1                                          8635769.0
# 2                                             6613.0
# 3                                         26772557.0
# 4                                           625628.0
#
#    Styrene-acrylonitrile (SAN) copolymers; primary forms - Import - Trade (USD)  \
# 0                                                NaN
# 1                                           583064.0
# 2                                                NaN
# 3                                          3856809.0
# 4                                                NaN
#
#    Tube; pipe or hose; rigid; of polyethylene - Import - Trade (USD)  \
# 0                                                NaN
# 1                                         15425077.0
# 2                                           112768.0
# 3                                          3990155.0
# 4                                          5679696.0
#
#    Tube; pipe or hose; rigid; of polypropylene - Import - Trade (USD)  \
# 0                                                NaN
# 1                                          6057782.0
# 2                                            32904.0
# 3                                          1337204.0
# 4                                           921824.0
#
#    Tube; pipe or hose; rigid; of polyvinyl chloride - Import - Trade (USD)  \
# 0                                                NaN
# 1                                          6265034.0
# 2                                            64723.0
# 3                                          2570083.0
# 4                                           625835.0
#
#    Urea resins; thiourea resins; in primary forms - Import - Trade (USD)  \
# 0                                                NaN
# 1                                          8793888.0
# 2                                              183.0
# 3                                           661240.0
# 4                                            96778.0
#
#    Vinyl chloride copolymers nes in primary forms - Import - Trade (USD)  \
# 0                                                NaN
# 1                                           431285.0
# 2                                              283.0
# 3                                           931732.0
# 4                                                NaN
#
#    Vinyl chloride-vinyl acetate copolymers; primary form - Import - Trade (USD)  \
# 0                                                NaN
# 1                                           653549.0
# 2                                                NaN
# 3                                           877328.0
# 4                                                NaN
#
#    Vinyl polymers; halogenated olefins; primary form; ne - Import - Trade (USD)  \
# 0                                                NaN
# 1                                          3825344.0
# 2                                                NaN
# 3                                         17135550.0
# 4                                            42138.0
#
#    Vinylidene chloride polymers in primary forms - Import - Trade (USD)
# 0                                                NaN
# 1                                            37692.0
# 2                                                NaN
# 3                                          4024234.0
# 4                                                NaN
#
# [5 rows x 123 columns]

# %% [markdown]
# From among them we pick the top decile of the products based on their total import values

# %%
top_imp = imp_dat.sum().sort_values(ascending=False)
top_imp.head()
# Out:
# Plastic articles nes - Import - Trade (USD)                                     3.867892e+10
# Polyethylene - specific gravity >0.94 in primary form - Import - Trade (USD)    2.042793e+10
# Polyethylene - specific gravity <0.94 in primary form - Import - Trade (USD)    1.913963e+10
# Polypropylene in primary forms - Import - Trade (USD)                           1.694545e+10
# Polymers of ethylene nes; in primary forms - Import - Trade (USD)               1.153100e+10
# dtype: float64

# %%
top_imp = top_imp[top_imp >= top_imp.quantile(q=0.90)].index

# %%
impcors = imp_dat.loc[:,imp_dat.columns.isin(top_imp)]
impcors.columns = impcors.columns.str[:-23]
impcors = impcors.corr()
impcors.head()
# Out:
#                                          Acrylic polymers nes; in primary forms  \
# Acrylic polymers nes; in primary forms                                 1.000000
# Boxes; cases; crates etc. of plastic                                   0.717739
# Plastic articles nes                                                   0.812479
# Plastic sheet; film; foil or strip; nes                                0.829129
# Polycarbonates; in primary forms                                       0.814361
#
#                                          Boxes; cases; crates etc. of plastic  \
# Acrylic polymers nes; in primary forms                               0.717739
# Boxes; cases; crates etc. of plastic                                 1.000000
# Plastic articles nes                                                 0.915061
# Plastic sheet; film; foil or strip; nes                              0.874761
# Polycarbonates; in primary forms                                     0.449538
#
#                                          Plastic articles nes  \
# Acrylic polymers nes; in primary forms               0.812479
# Boxes; cases; crates etc. of plastic                 0.915061
# Plastic articles nes                                 1.000000
# Plastic sheet; film; foil or strip; nes              0.913988
# Polycarbonates; in primary forms                     0.555987
#
#                                          Plastic sheet; film; foil or strip; nes  \
# Acrylic polymers nes; in primary forms                                  0.829129
# Boxes; cases; crates etc. of plastic                                    0.874761
# Plastic articles nes                                                    0.913988
# Plastic sheet; film; foil or strip; nes                                 1.000000
# Polycarbonates; in primary forms                                        0.439051
#
#                                          Polycarbonates; in primary forms  \
# Acrylic polymers nes; in primary forms                           0.814361
# Boxes; cases; crates etc. of plastic                             0.449538
# Plastic articles nes                                             0.555987
# Plastic sheet; film; foil or strip; nes                          0.439051
# Polycarbonates; in primary forms                                 1.000000
#
#                                          Polyethers nes; in primary forms  \
# Acrylic polymers nes; in primary forms                           0.958420
# Boxes; cases; crates etc. of plastic                             0.740036
# Plastic articles nes                                             0.850811
# Plastic sheet; film; foil or strip; nes                          0.837084
# Polycarbonates; in primary forms                                 0.746722
#
#                                          Polyethylene - specific gravity <0.94 in primary form  \
# Acrylic polymers nes; in primary forms                                            0.926397
# Boxes; cases; crates etc. of plastic                                              0.634352
# Plastic articles nes                                                              0.752014
# Plastic sheet; film; foil or strip; nes                                           0.766656
# Polycarbonates; in primary forms                                                  0.748871
#
#                                          Polyethylene - specific gravity >0.94 in primary form  \
# Acrylic polymers nes; in primary forms                                            0.889807
# Boxes; cases; crates etc. of plastic                                              0.480341
# Plastic articles nes                                                              0.603441
# Plastic sheet; film; foil or strip; nes                                           0.537366
# Polycarbonates; in primary forms                                                  0.961088
#
#                                          Polymers of ethylene nes; in primary forms  \
# Acrylic polymers nes; in primary forms                                     0.868856
# Boxes; cases; crates etc. of plastic                                       0.464179
# Plastic articles nes                                                       0.572945
# Plastic sheet; film; foil or strip; nes                                    0.498706
# Polycarbonates; in primary forms                                           0.964248
#
#                                          Polypropylene in primary forms  \
# Acrylic polymers nes; in primary forms                         0.865068
# Boxes; cases; crates etc. of plastic                           0.510091
# Plastic articles nes                                           0.630821
# Plastic sheet; film; foil or strip; nes                        0.573321
# Polycarbonates; in primary forms                               0.870628
#
#                                          Propylene copolymers in primary forms  \
# Acrylic polymers nes; in primary forms                                0.955422
# Boxes; cases; crates etc. of plastic                                  0.653605
# Plastic articles nes                                                  0.789501
# Plastic sheet; film; foil or strip; nes                               0.747139
# Polycarbonates; in primary forms                                      0.846653
#
#                                          Self-adhesive plates; sheets; film; plastic; w >20 cm  \
# Acrylic polymers nes; in primary forms                                            0.927956
# Boxes; cases; crates etc. of plastic                                              0.658903
# Plastic articles nes                                                              0.746081
# Plastic sheet; film; foil or strip; nes                                           0.683857
# Polycarbonates; in primary forms                                                  0.948980
#
#                                          Sheet/film not cellular/reinf polymers of ethylene
# Acrylic polymers nes; in primary forms                                            0.927522
# Boxes; cases; crates etc. of plastic                                              0.836024
# Plastic articles nes                                                              0.926510
# Plastic sheet; film; foil or strip; nes                                           0.914683
# Polycarbonates; in primary forms                                                  0.663547

# %% [markdown]
# ## Plot2
#
# The graph shows the correlations from different countries between overal imports within a significatn product group.
#
# For this, first we identified those products which
# 1. belong to the top 30 effective export products of the country (we continued to work with Indonesia),
# 2. had the highest opporunity gain value from among them,
#
# After that, we accessed the UN Comtrade data API through Quandl and downloaded all trade data related to that wider product group (in this case Plastics). Based on this, we calculated correlations between the the top 10% of imported products based on their import value.
#
# The workflow and graph can help those who are interested in producing a particular product type with significant opporunity gain. For them it shows those products from the same product group, which are also imported into the same countries as the original and shows their close relationship with other products based on their main import destinations. This allows users to shift their production line gainfully while still staying at the same geogprhically market. This graph and data can also provide a good picture of the country in terms of its opportunity- and production-related co-optations and the possible efficiency gaps in terms of its international economic relations.

# %%
sns.set(font_scale=2)
plt.figure(figsize=(20,15))
sns.heatmap(impcors, xticklabels=True, yticklabels=True, cmap='mako_r', annot=True, cbar=False)
